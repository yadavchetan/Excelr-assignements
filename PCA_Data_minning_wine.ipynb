# %%
#importing the Pandas library and creating the data frame from wine dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df= pd.read_csv('wine.csv')
df.head()
# Out:
#    Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0     1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1     1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2     1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3     1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4     1    13.24   2.59  2.87        21.0        118     2.80        2.69
#
#    Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline
# 0           0.28             2.29   5.64  1.04      3.92     1065
# 1           0.26             1.28   4.38  1.05      3.40     1050
# 2           0.30             2.81   5.68  1.03      3.17     1185
# 3           0.24             2.18   7.80  0.86      3.45     1480
# 4           0.39             1.82   4.32  1.04      2.93      735

# %%
# droipping the type  column as we will be checking correlation on the features

df2 = df.drop('Type',1)
df2.head()
# Out:
# C:\Users\yadav\AppData\Local\Temp\ipykernel_24928\2958184499.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df2 = df.drop('Type',1)
#    Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4    13.24   2.59  2.87        21.0        118     2.80        2.69
#
#    Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline
# 0           0.28             2.29   5.64  1.04      3.92     1065
# 1           0.26             1.28   4.38  1.05      3.40     1050
# 2           0.30             2.81   5.68  1.03      3.17     1185
# 3           0.24             2.18   7.80  0.86      3.45     1480
# 4           0.39             1.82   4.32  1.04      2.93      735

# %%
# lets check the correlation of the features for check whcih variables are strngly correlated
import seaborn as sns

correlation = df2.corr()
#sns.heatmap(df2.corr())

correlation.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_a619b_row0_col0, #T_a619b_row1_col1, #T_a619b_row2_col2, #T_a619b_row3_col3, #T_a619b_row4_col4, #T_a619b_row5_col5, #T_a619b_row6_col6, #T_a619b_row7_col7, #T_a619b_row8_col8, #T_a619b_row9_col9, #T_a619b_row10_col10, #T_a619b_row11_col11, #T_a619b_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a619b_row0_col1, #T_a619b_row0_col4 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_a619b_row0_col2 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_a619b_row0_col3 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_a619b_row0_col5, #T_a619b_row12_col8, #T_a619b_row12_col10 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_a619b_row0_col6 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_a619b_row0_col7, #T_a619b_row4_col3, #T_a619b_row9_col8, #T_a619b_row10_col4 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_a619b_row0_col8 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_a619b_row0_col9 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_a619b_row0_col10 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_a619b_row0_col11 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_a619b_row0_col12 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_a619b_row1_col0, #T_a619b_row2_col10, #T_a619b_row9_col2 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_a619b_row1_col2 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_a619b_row1_col3, #T_a619b_row1_col9 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_a619b_row1_col4 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_a619b_row1_col5, #T_a619b_row8_col2 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_a619b_row1_col6, #T_a619b_row5_col3 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_a619b_row1_col7, #T_a619b_row12_col11 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_a619b_row1_col8 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_a619b_row1_col10, #T_a619b_row3_col0, #T_a619b_row3_col12, #T_a619b_row6_col7, #T_a619b_row7_col4, #T_a619b_row7_col5, #T_a619b_row7_col6, #T_a619b_row7_col8, #T_a619b_row7_col11, #T_a619b_row10_col1, #T_a619b_row10_col2, #T_a619b_row10_col9, #T_a619b_row12_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a619b_row1_col11, #T_a619b_row3_col5, #T_a619b_row7_col12 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_a619b_row1_col12 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_a619b_row2_col0, #T_a619b_row4_col10 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_a619b_row2_col1, #T_a619b_row2_col12 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_a619b_row2_col3 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_a619b_row2_col4 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_a619b_row2_col5 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_a619b_row2_col6 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_a619b_row2_col7, #T_a619b_row10_col12 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_a619b_row2_col8 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_a619b_row2_col9 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_a619b_row2_col11, #T_a619b_row4_col2 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_a619b_row3_col1 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_a619b_row3_col2, #T_a619b_row10_col8 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_a619b_row3_col4 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_a619b_row3_col6, #T_a619b_row3_col8, #T_a619b_row11_col1 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_a619b_row3_col7 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_a619b_row3_col9 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_a619b_row3_col10 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_a619b_row3_col11 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_a619b_row4_col0 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_a619b_row4_col1, #T_a619b_row8_col9 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_a619b_row4_col5, #T_a619b_row5_col0 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_a619b_row4_col6 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_a619b_row4_col7, #T_a619b_row10_col0 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_a619b_row4_col8, #T_a619b_row9_col7 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_a619b_row4_col9 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_a619b_row4_col11 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_a619b_row4_col12 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_a619b_row5_col1, #T_a619b_row12_col7 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_a619b_row5_col2, #T_a619b_row7_col10 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_a619b_row5_col4 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_a619b_row5_col6 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_a619b_row5_col7 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_a619b_row5_col8 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_a619b_row5_col9 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_a619b_row5_col10 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_a619b_row5_col11 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_a619b_row5_col12, #T_a619b_row6_col12 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_a619b_row6_col0 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_a619b_row6_col1 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_a619b_row6_col2, #T_a619b_row10_col7 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_a619b_row6_col3, #T_a619b_row11_col9 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_a619b_row6_col4, #T_a619b_row9_col4 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_a619b_row6_col5 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_a619b_row6_col8 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_a619b_row6_col9 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_a619b_row6_col10 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_a619b_row6_col11 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_a619b_row7_col0 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_a619b_row7_col1, #T_a619b_row8_col10, #T_a619b_row12_col9 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_a619b_row7_col2 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_a619b_row7_col3 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_a619b_row7_col9 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_a619b_row8_col0 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_a619b_row8_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_a619b_row8_col3 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_a619b_row8_col4 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_a619b_row8_col5 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_a619b_row8_col6 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_a619b_row8_col7 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_a619b_row8_col11 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_a619b_row8_col12 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_a619b_row9_col0, #T_a619b_row12_col5 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_a619b_row9_col1, #T_a619b_row12_col4 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_a619b_row9_col3 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_a619b_row9_col5 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_a619b_row9_col6, #T_a619b_row12_col1 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_a619b_row9_col10 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_a619b_row9_col11 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_a619b_row9_col12 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_a619b_row10_col3, #T_a619b_row11_col3 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_a619b_row10_col5 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_a619b_row10_col6 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_a619b_row10_col11 {
#   background-color: #

# %%
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop


def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

# %%
print(get_top_abs_correlations(df2, 3))
# Phenol and flavanoids are strongly correlated so even after reomoving one feature we still have 12 features
# Out:
# Phenols     Flavanoids    0.864564
# Flavanoids  Dilution      0.787194
# Phenols     Dilution      0.699949
# dtype: float64

# %%
# Phenol and flavanoids are strongly correlated so even after reomoving one feature we still have 12 features
df3 = df2.drop('Flavanoids', 1)
#df4 = df3.drop('Phenols', 1)
# Out:
# C:\Users\yadav\AppData\Local\Temp\ipykernel_24928\1767813358.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df3 = df2.drop('Flavanoids', 1)

# %%
# now we have total 12 features in the dataset
df3.head()
# Out:
#    Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Nonflavanoids  \
# 0    14.23   1.71  2.43        15.6        127     2.80           0.28
# 1    13.20   1.78  2.14        11.2        100     2.65           0.26
# 2    13.16   2.36  2.67        18.6        101     2.80           0.30
# 3    14.37   1.95  2.50        16.8        113     3.85           0.24
# 4    13.24   2.59  2.87        21.0        118     2.80           0.39
#
#    Proanthocyanins  Color   Hue  Dilution  Proline
# 0             2.29   5.64  1.04      3.92     1065
# 1             1.28   4.38  1.05      3.40     1050
# 2             2.81   5.68  1.03      3.17     1185
# 3             2.18   7.80  0.86      3.45     1480
# 4             1.82   4.32  1.04      2.93      735

# %%
# in above tab we can see that the features in the dataset are of different scales so we will have to normalize these features by scalig 
# them in between (0 to 1)

from sklearn.preprocessing import StandardScaler

std_df_2 = StandardScaler().fit_transform(df3) #normalizing data

std_df_2
# Out:
# array([[ 1.51861254, -0.5622498 ,  0.23205254, ...,  0.36217728,
#          1.84791957,  1.01300893],
#        [ 0.24628963, -0.49941338, -0.82799632, ...,  0.40605066,
#          1.1134493 ,  0.96524152],
#        [ 0.19687903,  0.02123125,  1.10933436, ...,  0.31830389,
#          0.78858745,  1.39514818],
#        ...,
#        [ 0.33275817,  1.74474449, -0.38935541, ..., -1.61212515,
#         -1.48544548,  0.28057537],
#        [ 0.20923168,  0.22769377,  0.01273209, ..., -1.56825176,
#         -1.40069891,  0.29649784],
#        [ 1.39508604,  1.58316512,  1.36520822, ..., -1.52437837,
#         -1.42894777, -0.59516041]])

# %% [markdown]
# ## PCA

# %%
# scikit learn library makes it easy to get principal component
from sklearn.decomposition import PCA
 
pca = PCA(n_components=12)
principalcomponenets = pca.fit_transform(std_df_2)

# %%
pca.components_
# Out:
# array([[ 0.16662311, -0.27934476, -0.02370158, -0.28417931,  0.16729835,
#          0.41809434, -0.33492999,  0.33565192, -0.09519343,  0.32937266,
#          0.40256828,  0.32502665],
#        [-0.48284477, -0.22624548, -0.31664825,  0.0089848 , -0.29882049,
#         -0.06364516, -0.03026597, -0.03814281, -0.53033947,  0.28060561,
#          0.16590321, -0.36343973],
#        [-0.1974426 ,  0.04169516,  0.6360134 ,  0.5923123 ,  0.1842542 ,
#          0.17208161,  0.13672783,  0.17466933, -0.15784913,  0.13743408,
#          0.19949468, -0.08696464],
#        [-0.08615033,  0.522845  , -0.21431249,  0.09495009, -0.11901645,
#          0.18154484, -0.34578841,  0.46468927,  0.02018146, -0.42756848,
#          0.19295574, -0.2473513 ],
#        [-0.26006646, -0.11834745, -0.11123858,  0.02808164,  0.7819121 ,
#         -0.23893017, -0.41151519, -0.03558945, -0.06416836, -0.08578917,
#         -0.20493866, -0.11240102],
#        [-0.20952475, -0.53014243, -0.15328063,  0.10145133, -0.04529788,
#          0.09141895,  0.26272171,  0.54703553,  0.41575408, -0.10211362,
#         -0.25650382, -0.11622526],
#        [-0.06845128,  0.42032335, -0.15373605, -0.29879592,  0.34476152,
#         -0.0447192 ,  0.60033912,  0.33713563, -0.22688418,  0.22369856,
#         -0.06922199,  0.06702205],
#        [ 0.39912104,  0.09703319, -0.20685822,  0.42611847, -0.11607882,
#         -0.44557081, -0.2112943 ,  0.30876064, -0.01541271,  0.46982975,
#         -0.17229208,  0.0653568 ],
#        [ 0.49955707, -0.0960695 , -0.29452673,  0.18383695,  0.27426532,
#          0.3124503 ,  0.20951619, -0.2095794 ,  0.0454625 ,  0.04290824,
#          0.18363855, -0.56777907],
#        [-0.22929614,  0.29390425,  0.03249105, -0.06412663, -0.06105177,
#          0.460466  , -0.20674327, -0.14923193,  0.30607033,  0.50261458,
#         -0.44761057, -0.16867363],
#        [-0.21426388,  0.06567491, -0.50512483,  0.48698181,  0.07460791,
#          0.26732469,  0.12703075, -0.23206217,  0.01605803, -0.06957262,
#          0.0556546 ,  0.54978295],
#        [-0.26292745,  0.12086182, -0.05901186, -0.04812044,  0.06568636,
#         -0.33388768,  0.04945023, -0.09941244,  0.59972315,  0.25139674,
#          0.59492755, -0.0743828 ]])

# %%
#putting Components in dataframe for later

PCA_components = pd.DataFrame(principalcomponenets)

PCA_components
# Out:
#            0         1         2         3         4         5         6   \
# 0    3.195942 -1.433655  0.037766  0.086982  0.604186 -0.214372  0.578056
# 1    2.164482  0.341295 -1.937300 -0.413087 -0.100040 -0.936269  0.094246
# 2    2.163996 -1.027405  1.006095  0.708540 -0.542781  0.572569  0.369469
# 3    3.451585 -2.747487 -0.083941  0.509958 -0.520435  0.126526 -0.416962
# 4    0.743463 -0.870430  2.059030 -0.220716  0.307142 -0.404507  0.454568
# ..        ...       ...       ...       ...       ...       ...       ...
# 173 -3.055016 -2.224050 -0.510845  0.817219 -0.820565 -1.090057  0.946827
# 174 -2.275922 -1.762421  0.155645  0.420498  0.124771 -0.019482  0.125454
# 175 -2.275321 -2.764802 -0.975133  0.599151  1.194216  0.263803  0.709750
# 176 -1.955845 -2.300058 -0.514880 -0.455380  1.001792  1.168294  0.656500
# 177 -2.995179 -2.778008  0.852028  0.328848 -1.037875  0.312436 -0.034275
#
#            7         8         9         10        11
# 0   -0.145798  0.703246 -0.960619 -0.419447  0.542605
# 1   -1.023990 -0.257653 -0.105615 -0.145124  0.385293
# 2    0.231458 -1.176327 -0.180200 -0.275054  0.003706
# 3   -0.766889  0.125096 -0.058343  0.743656 -0.263786
# 4   -0.386121  0.339742  0.106847 -0.536502 -0.225306
# ..        ...       ...       ...       ...       ...
# 173  0.163916 -0.041177  0.310270  0.124505  0.163673
# 174  0.528805 -0.123633  0.199166  0.250070 -0.286971
# 175  0.021799 -0.018363  0.244559  0.505072  0.702881
# 176 -0.398416  0.096422 -0.448727  0.316303  0.343648
# 177  0.269757  0.738802  0.183677 -0.248372 -0.208128
#
# [178 rows x 12 columns]

# %%
# The amount of variance that each PCA has
var=pca.explained_variance_ratio_
var
# Out:
# array([0.32528185, 0.20807784, 0.11740471, 0.07492283, 0.06972545,
#        0.05344876, 0.04573435, 0.02812564, 0.02401902, 0.02040815,
#        0.01880261, 0.01404878])

# %%
# Cummulative variance of each PCA
var1=np.cumsum(np.round(var,4)*100)
var1
# Out:
# array([32.53, 53.34, 65.08, 72.57, 79.54, 84.88, 89.45, 92.26, 94.66,
#        96.7 , 98.58, 99.98])

# %%
# Variance plot for PCA components obtained 
plt.plot(var1,color='magenta')

# %%
#plotting the variance for each PC


PC = range(1, pca.n_components + 1)

plt.bar(PC, pca.explained_variance_ratio_, color='gold')
plt.xlabel('principal_components')
plt.ylabel('variance %')
plt.xticks(PC)
# Out:
# ([<matplotlib.axis.XTick at 0x1fc76ce1900>,
#   <matplotlib.axis.XTick at 0x1fc76d6aa40>,
#   <matplotlib.axis.XTick at 0x1fc72d693f0>,
#   <matplotlib.axis.XTick at 0x1fc729bba90>,
#   <matplotlib.axis.XTick at 0x1fc729ba050>,
#   <matplotlib.axis.XTick at 0x1fc729b9ea0>,
#   <matplotlib.axis.XTick at 0x1fc729bab90>,
#   <matplotlib.axis.XTick at 0x1fc729ba680>,
#   <matplotlib.axis.XTick at 0x1fc72c49b40>,
#   <matplotlib.axis.XTick at 0x1fc72c485e0>,
#   <matplotlib.axis.XTick at 0x1fc72c490c0>,
#   <matplotlib.axis.XTick at 0x1fc729b8820>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# we can see in the above plot that most of the variance is put in the first componenets
#Importance of each component decreases when going from1 to n, 1 PC is most important and n(12 in our case) is leat important

# %%
plt.scatter(PCA_components[0], PCA_components[1], alpha=.4, color='gold')

# %%
# Final Dataframe
final_df=pd.concat([df['Type'],pd.DataFrame(principalcomponenets[:,0:3],columns=['PC1','PC2','PC3'])],axis=1)
final_df
# Out:
#      Type       PC1       PC2       PC3
# 0       1  3.195942 -1.433655  0.037766
# 1       1  2.164482  0.341295 -1.937300
# 2       1  2.163996 -1.027405  1.006095
# 3       1  3.451585 -2.747487 -0.083941
# 4       1  0.743463 -0.870430  2.059030
# ..    ...       ...       ...       ...
# 173     3 -3.055016 -2.224050 -0.510845
# 174     3 -2.275922 -1.762421  0.155645
# 175     3 -2.275321 -2.764802 -0.975133
# 176     3 -1.955845 -2.300058 -0.514880
# 177     3 -2.995179 -2.778008  0.852028
#
# [178 rows x 4 columns]

# %%
# by visual inspection we can see that there are 3 clusters, we can also use intertia for surity

from sklearn.cluster import KMeans

inertias = []


#creating 10 k-means models while varying the number of clusters

for k in range(1,10):
    model = KMeans(n_clusters=k)
    
    
    #fit model to sample
    model.fit(PCA_components.iloc[:,:3])
    
    # append the intertia to the list of intertias
    inertias.append(model.inertia_)
    
plt.plot(range(1,10), inertias, '-p', color='gold')
plt.xlabel('number of clusters, k')
plt.ylabel('inertia')
plt.show()
# Out:
# D:\python\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# D:\python\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# D:\python\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# D:\python\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# D:\python\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# D:\python\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# D:\python\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# D:\python\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# D:\python\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Visualization of PCAs
fig=plt.figure(figsize=(16,12))
sns.scatterplot(data=final_df)
# Out:
# <AxesSubplot:>

# %%
#Model with 3 clusters 

model_f = KMeans(n_clusters=3)

model_f.fit(PCA_components.iloc[:,:2])

labels = model_f.predict(PCA_components.iloc[:,:2])

plt.scatter(PCA_components[0], PCA_components[1],  c=labels)

plt.show()
# Out:
# D:\python\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
